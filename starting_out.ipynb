# %% [markdown]
# <a href="https://colab.research.google.com/github/voperdev-lang/ml-learning/blob/main/starting_out.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!
